# %% [markdown]
# # Yahoo Finance 下載台積電股價資料

# %%
import yfinance as yf 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 台積電股價資料

# %%
TSMC = yf.Ticker("2330.TW")
TSMC.info
# Out:
# {'address1': 'Hsinchu Science Park',
#  'address2': 'No. 8, Li-Hsin Road 6',
#  'city': 'Hsinchu City',
#  'zip': '300096',
#  'country': 'Taiwan',
#  'phone': '886 3 563 6688',
#  'fax': '886 3 563 7000',
#  'website': 'https://www.tsmc.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Taiwan Semiconductor Manufacturing Company Limited, together with its subsidiaries, manufactures, packages, tests, and sells integrated circuits and other semiconductor devices in Taiwan, China, Europe, the Middle East, Africa, Japan, the United States, and internationally. It provides a range of wafer fabrication processes, including processes to manufacture complementary metal- oxide-semiconductor (CMOS) logic, mixed-signal, radio frequency, embedded memory, bipolar CMOS mixed-signal, and others. The company also offers customer and engineering support services; manufactures masks; and invests in technology start-up companies; researches, designs, develops, manufactures, packages, tests, and sells color filters; and provides investment services. Its products are used in high performance computing, smartphones, Internet of things, automotive, and digital consumer electronics. The company was incorporated in 1987 and is headquartered in Hsinchu City, Taiwan.',
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Dr. C. C.  Wei Ph.D.',
#    'title': 'Chairman & CEO',
#    'fiscalYear': 2023,
#    'totalPay': 459800000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jen-Chau  Huang',
#    'title': 'Senior VP of Finance & CFO',
#    'fiscalYear': 2023,
#    'totalPay': 88200000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Y. P. Chyn',
#    'title': 'Executive VP of Operations & Overseas Operations Office and Co-COO',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Y. J. Mii',
#    'title': 'Executive VP of Research & Development and Co-COO',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Horng-Dar  Lin',
#    'title': 'Vice President of Corporate Information Technology & Chief Information Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeff  Su',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Sylvia  Fang',
#    'title': 'Senior VP of Legal, General Counsel & Corporate Governance Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Elizabeth  Sun',
#    'title': 'Senior Director of Corporate Communication Division',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Li Mei  He Ho',
#    'title': 'Senior Vice President of Human Resources',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Wei-Jen  Lo',
#    'title': 'Senior Vice President of Corporate Strategy Development',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'compensationAsOfEpochDate': 1703980800,
#  'irWebsite': 'http://www.tsmc.com/english/investorRelations/index.htm',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 1085.0,
#  'open': 1090.0,
#  'dayLow': 1075.0,
#  'dayHigh': 1095.0,
#  'regularMarketPreviousClose': 1085.0,
#  'regularMarketOpen': 1090.0,
#  'regularMarketDayLow': 1075.0,
#  'regularMarketDayHigh': 1095.0,
#  'dividendRate': 16.0,
#  'dividendYield': 0.0147,
#  'exDividendDate': 1742256000,
#  'payoutRatio': 0.3455,
#  'fiveYearAvgDividendYield': 2.18,
#  'beta': 1.232,
#  'trailingPE': 26.562885,
#  'forwardPE': 18.421465,
#  'volume': 38876443,
#  'regularMarketVolume': 38876443,
#  'averageVolume': 37705037,
#  'averageVolume10days': 29802669,
#  'averageDailyVolume10Day': 29802669,
#  'bid': 1080.0,
#  'ask': 1085.0,
#  'marketCap': 27877651251200,
#  'fiftyTwoWeekLow': 574.0,
#  'fiftyTwoWeekHigh': 1100.0,
#  'priceToSalesTrailing12Months': 10.51441,
#  'fiftyDayAverage': 1046.02,
#  'twoHundredDayAverage': 924.375,
#  'trailingAnnualDividendRate': 15.5,
#  'trailingAnnualDividendYield': 0.014285714,
#  'currency': 'TWD',
#  'enterpriseValue': 26964691779584,
#  'profitMargins': 0.39123002,
#  'floatShares': 23355164560,
#  'sharesOutstanding': 25932699648,
#  'heldPercentInstitutions': 0.43447,
#  'impliedSharesOutstanding': 26176200704,
#  'bookValue': 153.888,
#  'priceToBook': 6.9856,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1727654400,
#  'earningsQuarterlyGrowth': 0.542,
#  'netIncomeToCommon': 1037299679232,
#  'trailingEps': 40.47,
#  'forwardEps': 57.73,
#  'lastSplitFactor': '1.005:1',
#  'lastSplitDate': 1247616000,
#  'enterpriseToRevenue': 10.17,
#  'enterpriseToEbitda': 15.002,
#  '52WeekChange': 0.8547008,
#  'SandP52WeekChange': 0.2738273,
#  'lastDividendValue': 4.5,
#  'lastDividendDate': 1742256000,
#  'exchange': 'TAI',
#  'quoteType': 'EQUITY',
#  'symbol': '2330.TW',
#  'underlyingSymbol': '2330.TW',
#  'shortName': 'TAIWAN SEMICONDUCTOR MANUFACTUR',
#  'longName': 'Taiwan Semiconductor Manufacturing Company Limited',
#  'firstTradeDateEpochUtc': 946947600,
#  'timeZoneFullName': 'Asia/Taipei',
#  'timeZoneShortName': 'CST',
#  'uuid': 'b6844710-30a4-30d3-8c32-2bd2ca535487',
#  'messageBoardId': 'finmb_380075',
#  'gmtOffSetMilliseconds': 28800000,
#  'currentPrice': 1075.0,
#  'targetHighPrice': 1600.0,
#  'targetLowPrice': 1170.0,
#  'targetMeanPrice': 1384.2167,
#  'targetMedianPrice': 1380.0,
#  'recommendationMean': 1.34375,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 30,
#  'totalCash': 2167600054272,
#  'totalCashPerShare': 83.601,
#  'ebitda': 1797362417664,
#  'totalDebt': 968509030400,
#  'quickRatio': 2.238,
#  'currentRatio': 2.567,
#  'totalRevenue': 2651375796224,
#  'debtToEquity': 24.081,
#  'revenuePerShare': 102.251,
#  'returnOnAssets': 0.12409,
#  'returnOnEquity': 0.28027,
#  'freeCashflow': 606226546688,
#  'operatingCashflow': 1600801341440,
#  'earningsGrowth': 0.541,
#  'revenueGrowth': 0.39,
#  'grossMargins': 0.54453,
#  'ebitdaMargins': 0.6779,
#  'operatingMargins': 0.47487998,
#  'financialCurrency': 'TWD',
#  'trailingPegRatio': 1.0742}

# %%
tsmc = yf.download('2330.TW',start='2016-01-01',end='2021-01-01')
tsmc
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close   Close    High     Low    Open    Volume
# Ticker         2330.TW 2330.TW 2330.TW 2330.TW 2330.TW   2330.TW
# Date
# 2016-01-04  107.623650   139.5   143.5   139.0   142.5  39169000
# 2016-01-05  106.466423   138.0   140.0   137.0   139.0  46381000
# 2016-01-06  104.537689   135.5   138.0   135.0   138.0  53617000
# 2016-01-07  102.608940   133.0   135.0   130.5   134.5  62539000
# 2016-01-08  103.380455   134.0   135.0   132.0   132.0  50123000
# ...                ...     ...     ...     ...     ...       ...
# 2020-12-25  473.202271   511.0   515.0   510.0   514.0  12327895
# 2020-12-28  476.906372   515.0   515.0   509.0   512.0  19087382
# 2020-12-29  476.906372   515.0   517.0   513.0   515.0  19907528
# 2020-12-30  486.166718   525.0   525.0   514.0   516.0  46292401
# 2020-12-31  490.796814   530.0   530.0   524.0   526.0  29970398
#
# [1218 rows x 6 columns]

# %%
tsmc = yf.download('2330.TW',period='5y', interval='1d')
avg_values = (tsmc['High'] + tsmc['Low']) / 2
avg_values.to_csv('tsmc_avg_prices.csv')
avg_values
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker      2330.TW
# Date
# 2019-12-17   340.00
# 2019-12-18   343.25
# 2019-12-19   338.50
# 2019-12-20   330.75
# 2019-12-23   331.75
# ...             ...
# 2024-12-11  1052.50
# 2024-12-12  1060.00
# 2024-12-13  1062.50
# 2024-12-16  1080.00
# 2024-12-17  1085.00
#
# [1216 rows x 1 columns]

# %%
avg_values = pd.read_csv('tsmc_avg_prices.csv')
avg_values
# Out:
#             Date  2330.TW
# 0     2019-12-17   340.00
# 1     2019-12-18   343.25
# 2     2019-12-19   338.50
# 3     2019-12-20   330.75
# 4     2019-12-23   331.75
# ...          ...      ...
# 1211  2024-12-11  1052.50
# 1212  2024-12-12  1060.00
# 1213  2024-12-13  1062.50
# 1214  2024-12-16  1080.00
# 1215  2024-12-17  1085.00
#
# [1216 rows x 2 columns]

# %%
# 繪製折線圖
plt.figure(figsize=(10, 4))
# 將Datetime轉換為datetime格式以便更好地處理時間軸
avg_values['Date'] = pd.to_datetime(avg_values['Date'])
# 設定x軸的刻度為每3個月一個標籤
plt.plot(avg_values['Date'], avg_values['2330.TW'], label='Average Price')
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator(interval=3))
plt.title('TSMC Average Prices Over Last 2 Year')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %%
#SEQ_LEN = 60
#FUTURE_PERIOD_PREDICT = 1 #day, how far into the future are we trying to predict?
#RATIO_TO_PREDICT = "avg"
# 設定參數
SEQ_LEN = 60  # 序列長度
FUTURE_PERIOD_PREDICT = 3  # 預測未來天數
RATIO_TO_PREDICT = "2330.TW"  # 要預測的欄位

# %%
def classify(current, future):
    if float(future) > float(current):
        return 1
    else:
        return 0

# %%
avg_values['future'] = avg_values[RATIO_TO_PREDICT].shift(-FUTURE_PERIOD_PREDICT)
avg_values['target'] = list(map(classify, avg_values[RATIO_TO_PREDICT], avg_values['future']))
avg_values
# Out:
#            Date  2330.TW   future  target
# 0    2019-12-17   340.00   330.75       0
# 1    2019-12-18   343.25   331.75       0
# 2    2019-12-19   338.50   333.25       0
# 3    2019-12-20   330.75   332.75       1
# 4    2019-12-23   331.75   332.75       1
# ...         ...      ...      ...     ...
# 1211 2024-12-11  1052.50  1080.00       1
# 1212 2024-12-12  1060.00  1085.00       1
# 1213 2024-12-13  1062.50      NaN       0
# 1214 2024-12-16  1080.00      NaN       0
# 1215 2024-12-17  1085.00      NaN       0
#
# [1216 rows x 4 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt


# 獲取所有數據並進行預處理
all_data = avg_values[RATIO_TO_PREDICT].values.reshape(-1, 1)

# 使用MinMaxScaler進行整體歸一化
scaler = MinMaxScaler()
all_data_scaled = scaler.fit_transform(all_data)

# 應用EMA平滑處理到整個數據集
def apply_ema(data, gamma=0.1):
    ema = 0.0
    smoothed_data = np.zeros_like(data)
    for i in range(len(data)):
        ema = gamma * data[i] + (1 - gamma) * ema
        smoothed_data[i] = ema
    return smoothed_data

all_data_smoothed = apply_ema(all_data_scaled)

# 計算分割點
total_len = len(all_data_smoothed)
train_len = int(0.8 * total_len)
valid_len = int(0.1 * total_len)
test_len = total_len - train_len - valid_len

# 創建序列數據的函數
def create_sequences(data, seq_length, future_period):
    X, y = [], []
    for i in range(len(data) - seq_length - future_period + 1):
        X.append(data[i:(i + seq_length)]) #0-4
        y.append(data[i + seq_length:(i + seq_length + future_period)]) #5   
    return np.array(X), np.array(y)

# 創建完整的序列數據
X_all, y_all = create_sequences(all_data_smoothed, SEQ_LEN, FUTURE_PERIOD_PREDICT)

# 分割序列數據
train_end = train_len - SEQ_LEN
val_end = train_len + valid_len - SEQ_LEN

X_train = X_all[:train_end]
y_train = y_all[:train_end]

X_valid = X_all[train_end:val_end]
y_valid = y_all[train_end:val_end]

X_test = X_all[val_end:]
y_test = y_all[val_end:]

# 重塑數據
if len(X_train) > 0:
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
if len(X_valid) > 0:
    X_valid = X_valid.reshape((X_valid.shape[0], X_valid.shape[1], 1))
if len(X_test) > 0:
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], ))
y_valid = y_valid.reshape((y_valid.shape[0], y_valid.shape[1], ))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], ))
print(y_train.shape)
print(y_valid.shape)
print(y_test.shape)

# 畫出預測圖表
plt.figure(figsize=(15, 5))

# 繪製訓練數據
if len(y_train) > 0:
    plt.plot(range(y_train.shape[0]), y_train[:, 0], 
             color='blue', label='Train', alpha=0.7)

# 繪製驗證數據
if len(y_valid) > 0:
    plt.plot(range(y_train.shape[0], y_train.shape[0] + y_valid.shape[0]), 
             y_valid[:, 0], color='gray', label='Valid', alpha=0.7)

# 繪製測試數據
if len(y_test) > 0:
    plt.plot(range(y_train.shape[0] + y_valid.shape[0], 
                   y_train.shape[0] + y_valid.shape[0] + y_test.shape[0]),
             y_test[:, 0], color='black', label='Test', alpha=0.7)

plt.title('Data')
plt.xlabel('Time(days)')
plt.ylabel('price')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# 打印數據集大小
print(f"總數據量: {len(all_data_smoothed)}")
print(f"訓練集大小: {len(y_train)}")
print(f"驗證集大小: {len(y_valid)}")
print(f"測試集大小: {len(y_test)}")
# Out:
# (912, 3)
# (121, 3)
# (121, 3)
# 總數據量: 1216
# 訓練集大小: 912
# 驗證集大小: 121
# 測試集大小: 121

# %%
print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
print(y_train.shape)
print(y_valid.shape)
print(y_test.shape)
print(y_train[0])
print(y_valid[0])
print(y_test[0])
# Out:
# (912, 60, 1)
# (121, 60, 1)
# (121, 60, 1)
# (912, 3)
# (121, 3)
# (121, 3)
# [0.05315892 0.05089669 0.0496908 ]
# [0.38966701 0.39087226 0.39171981]
# [0.76560418 0.77582111 0.78418623]

# %% [markdown]
# # LSTM

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import math

# %%
# 定義LSTM模型
class LSTMModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(LSTMModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size, 50, batch_first=True)
        self.dropout1 = nn.Dropout(0.2)
        self.lstm2 = nn.LSTM(50, 60, batch_first=True)
        self.dropout2 = nn.Dropout(0.3)
        self.lstm3 = nn.LSTM(60, 80, batch_first=True)
        self.dropout3 = nn.Dropout(0.4)
        self.lstm4 = nn.LSTM(80, 120, batch_first=True)
        self.dropout4 = nn.Dropout(0.5)
        
        # 加入Attention層
        self.attention = nn.MultiheadAttention(120, num_heads=4, batch_first=True)
        self.layer_norm = nn.LayerNorm(120)
        
        self.fc = nn.Linear(120, output_size)


    def forward(self, x):
        
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        x, _ = self.lstm3(x)
        x = self.dropout3(x)
        x, _ = self.lstm4(x)
        x = self.dropout4(x)
        
        
        x = self.fc(x[:, -1, :])
        return x

# %%
# 創建數據加載器
class StockDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.FloatTensor(X)
        self.y = torch.FloatTensor(y)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]
    
# 初始化數據加載器
train_dataset = StockDataset(X_train, y_train)
valid_dataset = StockDataset(X_valid, y_valid)
test_dataset = StockDataset(X_test, y_test)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
# 初始化模型
import copy
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMModel(input_size=1, output_size=FUTURE_PERIOD_PREDICT).to(device)

# 定義損失函數和優化器
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# 訓練模型
num_epochs = 60
train_losses = []
valid_losses = []

# Early stopping 參數
patience = 10  # 容忍多少個epoch驗證損失沒有改善
min_delta = 0.0001  # 最小改善閾值
best_loss = float('inf')
patience_counter = 0
best_model = None

for epoch in range(num_epochs):
    # 訓練階段
    model.train()
    train_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch.squeeze())
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
    
    # 驗證階段
    model.eval()
    valid_loss = 0
    with torch.no_grad():
        for X_batch, y_batch in valid_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch.squeeze())
            valid_loss += loss.item()
    
    train_losses.append(train_loss/len(train_loader))
    valid_losses.append(valid_loss/len(valid_loader))
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_losses[-1]:.4f}, Valid Loss: {valid_losses[-1]:.4f}')
    
    # Early stopping 檢查
    '''
    current_loss = valid_losses[-1]
    if current_loss < best_loss - min_delta:
        best_loss = current_loss
        patience_counter = 0
        best_model = copy.deepcopy(model.state_dict())
    else:
        patience_counter += 1
        
    if patience_counter >= patience:
        print(f'Early stopping triggered at epoch {epoch+1}')
        model.load_state_dict(best_model)  # 恢復最佳模型
        break
    '''
# Out:
# Epoch [1/60], Train Loss: 0.0432, Valid Loss: 0.0571
# Epoch [2/60], Train Loss: 0.0160, Valid Loss: 0.0801
# Epoch [3/60], Train Loss: 0.0147, Valid Loss: 0.0585
# Epoch [4/60], Train Loss: 0.0080, Valid Loss: 0.0185
# Epoch [5/60], Train Loss: 0.0042, Valid Loss: 0.0095
# Epoch [6/60], Train Loss: 0.0033, Valid Loss: 0.0093
# Epoch [7/60], Train Loss: 0.0031, Valid Loss: 0.0043
# Epoch [8/60], Train Loss: 0.0033, Valid Loss: 0.0110
# Epoch [9/60], Train Loss: 0.0028, Valid Loss: 0.0050
# Epoch [10/60], Train Loss: 0.0024, Valid Loss: 0.0088
# Epoch [11/60], Train Loss: 0.0025, Valid Loss: 0.0065
# Epoch [12/60], Train Loss: 0.0025, Valid Loss: 0.0038
# Epoch [13/60], Train Loss: 0.0023, Valid Loss: 0.0151
# Epoch [14/60], Train Loss: 0.0025, Valid Loss: 0.0037
# Epoch [15/60], Train Loss: 0.0025, Valid Loss: 0.0046
# Epoch [16/60], Train Loss: 0.0021, Valid Loss: 0.0070
# Epoch [17/60], Train Loss: 0.0020, Valid Loss: 0.0067
# Epoch [18/60], Train Loss: 0.0018, Valid Loss: 0.0048
# Epoch [19/60], Train Loss: 0.0019, Valid Loss: 0.0022
# Epoch [20/60], Train Loss: 0.0018, Valid Loss: 0.0040
# Epoch [21/60], Train Loss: 0.0017, Valid Loss: 0.0036
# Epoch [22/60], Train Loss: 0.0015, Valid Loss: 0.0082
# Epoch [23/60], Train Loss: 0.0015, Valid Loss: 0.0042
# Epoch [24/60], Train Loss: 0.0015, Valid Loss: 0.0061
# Epoch [25/60], Train Loss: 0.0015, Valid Loss: 0.0053
# Epoch [26/60], Train Loss: 0.0016, Valid Loss: 0.0045
# Epoch [27/60], Train Loss: 0.0016, Valid Loss: 0.0046
# Epoch [28/60], Train Loss: 0.0015, Valid Loss: 0.0034
# Epoch [29/60], Train Loss: 0.0013, Valid Loss: 0.0017
# Epoch [30/60], Train Loss: 0.0015, Valid Loss: 0.0047
# Epoch [31/60], Train Loss: 0.0014, Valid Loss: 0.0040
# Epoch [32/60], Train Loss: 0.0012, Valid Loss: 0.0040
# Epoch [33/60], Train Loss: 0.0014, Valid Loss: 0.0022
# Epoch [34/60], Train Loss: 0.0013, Valid Loss: 0.0031
# Epoch [35/60], Train Loss: 0.0012, Valid Loss: 0.0033
# Epoch [36/60], Train Loss: 0.0013, Valid Loss: 0.0042
# Epoch [37/60], Train Loss: 0.0013, Valid Loss: 0.0010
# Epoch [38/60], Train Loss: 0.0013, Valid Loss: 0.0041
# Epoch [39/60], Train Loss: 0.0011, Valid Loss: 0.0020
# Epoch [40/60], Train Loss: 0.0013, Valid Loss: 0.0025
# Epoch [41/60], Train Loss: 0.0012, Valid Loss: 0.0021
# Epoch [42/60], Train Loss: 0.0012, Valid Loss: 0.0045
# Epoch [43/60], Train Loss: 0.0011, Valid Loss: 0.0045
# Epoch [44/60], Train Loss: 0.0011, Valid Loss: 0.0031
# Epoch [45/60], Train Loss: 0.0010, Valid Loss: 0.0024
# Epoch [46/60], Train Loss: 0.0011, Valid Loss: 0.0017
# Epoch [47/60], Train Loss: 0.0011, Valid Loss: 0.0026
# Epoch [48/60], Train Loss: 0.0011, Valid Loss: 0.0037
# Epoch [49/60], Train Loss: 0.0010, Valid Loss: 0.0057
# Epoch [50/60], Train Loss: 0.0010, Valid Loss: 0.0024
# Epoch [51/60], Train Loss: 0.0009, Valid Loss: 0.0026
# Epoch [52/60], Train Loss: 0.0008, Valid Loss: 0.0029
# Epoch [53/60], Train Loss: 0.0009, Valid Loss: 0.0018
# Epoch [54/60], Train Loss: 0.0009, Valid Loss: 0.0040
# Epoch [55/60], Train Loss: 0.0009, Valid Loss: 0.0053
# Epoch [56/60], Train Loss: 0.0008, Valid Loss: 0.0014
# Epoch [57/60], Train Loss: 0.0008, Valid Loss: 0.0017
# Epoch [58/60], Train Loss: 0.0008, Valid Loss: 0.0022
# Epoch [59/60], Train Loss: 0.0008, Valid Loss: 0.0045
# Epoch [60/60], Train Loss: 0.0007, Valid Loss: 0.0005

# %%
# 繪製訓練損失曲線
plt.figure(figsize=(10,5))
plt.plot(train_losses, label='Train Loss')
plt.plot(valid_losses, label='Valid Loss')
plt.title('Training & Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True)
plt.legend()
plt.show()

# 預測和可視化
def plot_series(x_data, y, y_pred):
    plt.figure(figsize=(12, 8))
    plt.plot(range(len(x_data)), x_data, label='Input Series', alpha=0.3)
    
    input_len = len(x_data)
    plt.plot(range(input_len, input_len + len(y)), y, 
             label='True Future', alpha=0.8)
    plt.plot(range(input_len, input_len + len(y_pred)), y_pred, 
             label='Predicted Future', alpha=0.8)
    
    plt.legend()
    plt.title(f'{RATIO_TO_PREDICT} Stock Price Prediction')
    plt.xlabel('Time Steps')
    plt.ylabel('Price (TWD)')
    plt.grid(True)
    plt.show()

def show_prediction_with_mae():
    x, y_true = next(iter(valid_loader))
    x, y_true = x.to(device), y_true.to(device)
    
    model.eval()
    with torch.no_grad():
        y_pred = model(x)
    
    x = x[0].cpu().numpy()
    y_true = y_true[0].cpu().numpy()
    y_pred = y_pred[0].cpu().numpy()
    
    x_temp = x[:, 0] * (scaler.data_max_[0] - scaler.data_min_[0]) + scaler.data_min_[0]
    y_true = y_true * (scaler.data_max_[0] - scaler.data_min_[0]) + scaler.data_min_[0]
    y_pred = y_pred * (scaler.data_max_[0] - scaler.data_min_[0]) + scaler.data_min_[0]
    
    plot_series(x_temp, y_true, y_pred)
    
    mae = np.mean(np.abs(y_pred - y_true))
    print(f'MAE: {mae:.4f}')

# 顯示預測結果
show_prediction_with_mae()
# Out:
# MAE: 0.8580

# %%
# 1. 準備測試數據
X_test_tensor = torch.FloatTensor(X_test).to(device)

# 2. 進行預測
with torch.no_grad():
    predicted = model(X_test_tensor).cpu().numpy()

# 3. 數據轉換
# 將預測值轉回原始比例
predicted = predicted.reshape(-1, 1)
predicted_original = scaler.inverse_transform(predicted)

# 將實際值轉回原始比例
actual_original = scaler.inverse_transform(y_test.reshape(-1,1))

# 4. 取樣（每5個數據點取1個）
daily_indices = range(0, len(actual_original), 3)
daily_indices2 = range(0, len(predicted_original), 3)
actual_daily = actual_original[daily_indices]
predicted_daily = predicted_original[daily_indices2]

# 5. 繪製圖表
plt.figure(figsize=(10,5))
plt.plot(range(len(actual_daily)), actual_daily, label='Actual')
plt.plot(range(len(predicted_daily)), predicted_daily, label='Predicted')
plt.title('Actual vs Predicted (Test Set)')
plt.xlabel('Time steps')
plt.ylabel('Price')
plt.grid(True)
plt.legend()
plt.show()
